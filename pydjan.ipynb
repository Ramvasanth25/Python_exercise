# %%
#1
print('Welcome')
# Out:
# Welcome

# %%
#2
w=input()
print(w)
# Out:
# Hi
# Hi

# %%
#3
w=input("Enter a Message:")
print("Message:",w)
# Out:
# Enter a Message:Welcome to India
# Message: Welcome to India

# %%
#4
c = int(input("Enter an integer number: "))
print("The integer number is:", c)
# Out:
# Enter an integer number: 23
# The integer number is: 23

# %%
#5
c = float(input("Enter an fractional number: "))
print("The Fractional number is:", c)
# Out:
# Enter an fractional number: 2.5
# The Fractional number is: 2.5

# %%
#6
a=float(input())
print("%.2f"%a)
#print("{:.2f}".format(a))
# Out:
# 2.123845
# 2.12

# %%
#7
a=int(input())
print(hex(a))
# Out:
# 26
# 0x1a

# %%
#8
a=int(input())
print(oct(a))
# Out:
# 26
# 0o32

# %%
#9
s = input()
num = int(s,16)
print(num)
# Out:
# 1A
# 26

# %%
#10
s = input()
num = int(s,8)
print(num)
# Out:
# 32
# 26

# %%
#11
c=input()
print(ord(c))
# Out:
# A
# 65

# %%
#12
s=int(input())
print(chr(s))
# Out:
# 51
# 3

# %%
#13
a=int(input())
b=int(input())
print(a,b)
# Out:
# 10
# 20
# 10 20

# %%
#14
a=int(input())
b=int(input())
print(a,b, sep='\t')
# Out:
# 10
# 20
# 10	20

# %%
#15
a=int(input())
b=int(input())
print(a,b, sep='\n')
# Out:
# 10
# 20
# 10
# 20

# %%
#16
a=input()
print(("'{}'".format(a)))
# Out:
# A
# 'A'

# %%
#16
a=input()
print("'"+a+"'")
# Out:
# A
# 'A'

# %%
#17
a=input()
print(('"{}"'.format(a)))
# Out:
# hi world
# "hi world"

# %%
#18
d=int(input())
m=int(input())
y=int(input())
print("{0}/{1}/{2}".format(d,m,y))
# Out:
# 12
# 4
# 2006
# 12/4/2006

# %%
#19
a=int(input())
print("+{}".format(a))
# Out:
# 2
# +2

# %%
#20
a=input()
print(len(a))
# Out:
# 234
# 3

# %%
#21
r=int(input())
n=input()
print("Roll No:{0} ,Name:{1}".format(r,n))
# Out:
# 123
# Ram
# Roll No:123 ,Name:Ram

# %%
#22
a=int(input())
b=int(input())
print("\n",a,"\n",b)
# Out:
# 20
# 40
#
#  20
#  40

# %%
#22
a=int(input())
b=int(input())
c=int(input())
print(a,b,c, sep='\n')
# Out:
# 20
# 30
# 40
# 20
# 30
# 40

# %%
#22
a=int(input())
b=int(input())
c=int(input())
n="\n"
print(n,a,n,b,n,c)
# Out:
# 20
# 30
# 40
#
#  20
#  30
#  40

# %%
#23
b=input()
print("Blood Group:",b)
# Out:
# O
# Blood Group: O

# %%
#24
# Python Program to get time as user input and print in HH:MM:SS format

h=input("Enter Hours: ")
m=input("Enter Minutes: ")
s=input("Enter Seconds: ")

print(h + ":" + m + ":" + s)
# Out:
# Enter Hours: 23
# Enter Minutes: 45
# Enter Seconds: 23
# 23:45:23

# %%
#25
# Python Program to print address in multiple lines using \n

print("3,Myleripalayam,\nCoimbatore,\n625513")
# Out:
# 3,Myleripalayam,
# Coimbatore,
# 625513

# %%
Ex2

# %%
#6
a=int(input())
b=int(input())
temp=a
a=b
b=temp
print(a,b)
# Out:
# 2
# 3
# 3 2

# %%
#7
a=int(input())
b=int(input())
a,b=b,a
print(a,b)
# Out:
# 2
# 3
# 3 2

# %%
#8
a=int(input())
print(a%10)
# Out:
# 23
# 3
