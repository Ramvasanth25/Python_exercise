# %%
#1
a=int(input())
b=int(input())
print(a+b)
# Out:
# 2
# 3
# 5

# %%
#2
a=int(input())
b=int(input())
print(a-b)
# Out:
# 4
# 2
# 2

# %%
#3
a=int(input())
b=int(input())
print(a*b)
# Out:
# 3
# 2
# 6

# %%
#4
a=int(input())
b=int(input())
print(a/b)
# Out:
# 4
# 2
# 2.0

# %%
#5
a=int(input())
b=int(input())
print(a//b)
# Out:
# 0

# %%
#6
a=int(input())
b=int(input())
temp=a
a=b
b=temp
print(a,b)
# Out:
# 2
# 3
# 3 2

# %%
#7
a=int(input())
b=int(input())
a,b=b,a
print(a,b)
# Out:
# 2
# 3
# 3 2

# %%
#8
a=int(input())
print(a%10)
# Out:
# 23
# 3

# %%
#9
n=int(input())
print(n//10)
# Out:
# 234
# 23

# %%
#10
n=int(input())
c=n//100
d=n%10
print(c+d)
# Out:
# 234
# 6

# %%
#11
n=int(input())
print((n//10)%10)
# Out:
# 234
# 3

# %%
#12
n=int(input())
print(abs(n))
# Out:
# 2
# 2

# %%
#13
n=int(input())
print(n**2)
# Out:
# 4
# 16

# %%
#14
n=int(input())
print(n**3)
# Out:
# 3
# 27

# %%
#15
a=int(input())
b=int(input())
c=int(input())
d=a+b+c
print(int(d/3))
# Out:
# 1
# 2
# 3
# 2

# %%
#16
a=int(input())
b=int(input())
if a==b:
  print('True')
else:
  print("False")
# Out:
# 2
# 3
# False

# %%
#18
a=int(input())
if a>0:
  print('Positive')
else:
  print('Negative')
# Out:
# -1
# Negative

# %%
#19
a=int(input())
b=int(input())
c=int(input())
if a>b and a>c:
  print("a is greater")
elif b>a and b>c:
  print("b is greater")
else:
  print("c is greater")
# Out:
# 3
# 4
# 2
# b is greater

# %%
#20
n=int(input())
if n>=50:
  print("Pass")
else:
  print("Fail")
# Out:
# 45
# Fail

# %%
a=834344
b=len(str(a))
if a<1000:
    if b==1:
      print("Single")
    elif b==2:
      print("Two digit")
    else:
      print("Three digit")

# %%
a=int(input())
b=a%100
c=a//100
if b==c:
  print("Equal")
else:
  print("Not Equal")
# Out:
# 2323
# Equal
